# %%
import pandas as pd
import numpy as np
import pickle
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score

# %%
df = pd.read_csv("C:/Users/ASUS/Downloads/IceCreamData.csv")
df.head()
# Out:
#    Temperature     Revenue
# 0    24.566884  534.799028
# 1    26.005191  625.190122
# 2    27.790554  660.632289
# 3    20.595335  487.706960
# 4    11.503498  316.240194

# %%
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    float64
# dtypes: float64(2)
# memory usage: 7.9 KB

# %%
X = df['Temperature']
y = df['Revenue']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

# %%
len(y_test)
# Out:
# 100

# %%
model = LinearRegression()

# %%
y_test.ndim
# Out:
# 1

# %%
np.array([X_train]).ndim
# Out:
# 2

# %%
model.fit(np.array([X_train]).reshape(-1, 1), y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(np.array(X_test).reshape(-1, 1))

# %%
y_pred
# Out:
# array([ 294.7445757 ,  359.92287678,  808.36180474,  739.26939855,
#         521.79262727,  393.57764619,  393.62978734,  399.06519545,
#         658.58102661,  943.45982365,  661.54764945,  956.13875657,
#         654.51127337,  728.15827284,  492.26058618,  443.65929876,
#         654.62694289,  601.84239667,  557.93908384,  671.29699994,
#         209.99606323, 1009.45931059,  310.59451772,  529.47675682,
#         650.28995785,  589.33101906,  449.55152631,  630.10723105,
#         451.19931802,  356.04705414,  663.96732814,  412.87617938,
#         621.99129447,  157.68283373,  433.47261266,  129.33532581,
#         662.45588701,  575.51189043,  585.15949747,  565.42806474,
#         600.34418804,  509.02424541,  450.49642638,  940.07230202,
#         660.31328889,  464.87718037,  592.10002649,  439.98961347,
#         468.24007328,  358.93832621,  263.63962607,  634.54737971,
#         659.69872902,  336.16057157,  283.64179382,  744.06805371,
#         390.26644507,  840.51108284,  493.03079397,  437.49844884,
#         744.43453837,  570.01073785,  245.57987039,  529.51448199,
#         534.57518349,  346.57163721,  253.71086444,  442.46200156,
#         292.06442728,  260.95031922,  360.08868143,  717.88268158,
#         238.50597814,  453.95422299,  267.03804198,  611.51756743,
#         525.50799036,  441.8937637 ,  591.98769734,  666.87608446,
#         452.94430828,  169.50581593,  589.2695744 ,  546.0923272 ,
#         631.24625743,  370.28229183,  863.21788053,  457.49542686,
#         614.50049167,  445.25937916,  571.38546124,  196.3093759 ,
#         449.01998315,  440.24986688,  563.97047337,  199.61106083,
#         442.99056832,  448.94781674,  681.52806812,  828.53770574])

# %%
r2_score(y_test, y_pred)
# Out:
# 0.9790531399759024

# %%
print(model.predict([[5]]))
# Out:
# [151.08391522]

# %%
with open('model.pkl', 'wb') as file:
    pickle.dump(model, file)
